# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://RAFET:password@cluster0.bi02f.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
db = client["SchoolServicesSystemDatabase"]
collection = db["students"]

data = {"name":"RAFET","age":22}

# %%
collection.insert_one(data)

# %%
data = [
  { "name": "Amy", "age":22},
  { "name": "Hannah", "age":24},
  { "name": "Michael", "age":20},
  { "name": "Sandy", "age":19},
  { "name": "Betty", "age":18},
  { "name": "Richard", "age":22},
  { "name": "Susan", "age":26},
  { "name": "Vicky", "age":28},
  { "name": "Ben", "age":20},
  { "name": "William", "age":29},
  { "name": "Chuck", "age":23},
  { "name": "Viola", "age":21}
    ]

# %%
collection.insert_many(data)
